# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
df_merged = pd.read_csv('1.1 Cleaning Output.csv')

# %%
df_merged
# Out:
#         Unnamed: 0         Username  \
# 0                0       XavierNaxa
# 1                1       XavierNaxa
# 2                2       XavierNaxa
# 3                3       XavierNaxa
# 4                4       XavierNaxa
# ...            ...              ...
# 152262      152262         amirapis
# 152263      152263         Mrzach17
# 152264      152264         Mrzach17
# 152265      152265  Belalan60727537
# 152266      152266         BBengtvz
#
#                                                      Text  \
# 0       iPhone paling releven dibeli tahun 2022\n\niPh...
# 1       Tempoh menunggu dos penggalak bagi penerima do...
# 2       Melihat cara kerajaan mahupun pembangkang meny...
# 3       Penatlah dapat sorang menteri perasan cantik n...
# 4       Apakah produk Apple yang berjaya anda miliki p...
# ...                                                   ...
# 152262  @SyedSaddiq Abah kau yg plan semua ni sadiq. T...
# ...

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd

# Create a new instance of the VADER analyzer
analyzer = SentimentIntensityAnalyzer()

# Convert the 'Translated Cleaned Text' column to string type
df_merged['translated cleaned'] = df_merged['translated cleaned'].astype(str)

# Apply the polarity_scores() method to calculate sentiment scores for each text
df_merged['sentiment Scores'] = df_merged['translated cleaned'].apply(lambda text: analyzer.polarity_scores(text))

# Extract the compound score from the sentiment scores
df_merged['sentiment'] = df_merged['sentiment Scores'].apply(lambda scores: scores['compound'])

# %%
result = df_merged[df_merged['Text'].str.contains('ko ade masalah trust issue ni Ming')]
result
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Username, Text, Date Created, Number of Likes, Number of Retweet, Number of Replies, Source of Tweet, User ID, Conversation ID, status, Category, translated, translated cleaned, sentiment Scores, sentiment, sentiment_label]
# Index: []

# %%
sample = 'delicious'


# Apply the polarity_scores() method to calculate sentiment scores for the text
sentiment_scores = analyzer.polarity_scores(sample)

# Extract the compound score from the sentiment scores
sentiment = sentiment_scores['compound']

# Print the sentiment score
print("Sentiment score for the text: ", sentiment)
# Out:
# Sentiment score for the text:  0.5719

# %%
# Import the SentimentIntensityAnalyzer class
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Create an instance of the SentimentIntensityAnalyzer class
analyzer = SentimentIntensityAnalyzer()

# Split the sample text into a list of words
words = sample.split()

# Create an empty list to store the polarity scores of each word
polarity_scores = []

# Loop through each word in the list of words
for word in words:
    # Apply the polarity_scores() method to calculate sentiment scores for the word
    sentiment_scores = analyzer.polarity_scores(word)
    # Extract the compound score from the sentiment scores
    sentiment = sentiment_scores['compound']
    # Append the compound score to the list of polarity scores
    polarity_scores.append(sentiment)

# Print the table of words and their corresponding polarity scores
print("Word\tPolarity Score")
for i in range(len(words)):
    print(words[i], "\t", polarity_scores[i])
# Out:
# Word	Polarity Score
# politicians 	 0.0
# bad 	 -0.5423
# sitting 	 0.0
# melaka 	 0.0
# eligible 	 0.0
# sitting 	 0.0
# good 	 0.4404
# living 	 0.0
# harmoniously 	 0.4404
# fellow 	 0.0
# citizens 	 0.0

# %%
df_merged
# Out:
#         Unnamed: 0         Username  \
# 0                0       XavierNaxa
# 1                1       XavierNaxa
# 2                2       XavierNaxa
# 3                3       XavierNaxa
# 4                4       XavierNaxa
# ...            ...              ...
# 152262      152262         amirapis
# 152263      152263         Mrzach17
# 152264      152264         Mrzach17
# 152265      152265  Belalan60727537
# 152266      152266         BBengtvz
#
#                                                      Text  \
# 0       iPhone paling releven dibeli tahun 2022\n\niPh...
# 1       Tempoh menunggu dos penggalak bagi penerima do...
# 2       Melihat cara kerajaan mahupun pembangkang meny...
# 3       Penatlah dapat sorang menteri perasan cantik n...
# 4       Apakah produk Apple yang berjaya anda miliki p...
# ...                                                   ...
# 152262  @SyedSaddiq Abah kau yg plan semua ni sadiq. T...
# ...

# %%
# Define a function to label the sentiment
def label_sentiment(row):
    if row['sentiment'] > 0.05:
        return 'Positive'
    elif row['sentiment'] < -0.05:
        return 'Negative'
    else:
        return 'Neutral'


# Apply the function to each row and create a new column
df_merged['sentiment_label'] = df_merged.apply(label_sentiment, axis=1)


df_merged
# Out:
#         Unnamed: 0         Username  \
# 0                0       XavierNaxa
# 1                1       XavierNaxa
# 2                2       XavierNaxa
# 3                3       XavierNaxa
# 4                4       XavierNaxa
# ...            ...              ...
# 152262      152262         amirapis
# 152263      152263         Mrzach17
# 152264      152264         Mrzach17
# 152265      152265  Belalan60727537
# 152266      152266         BBengtvz
#
#                                                      Text  \
# 0       iPhone paling releven dibeli tahun 2022\n\niPh...
# 1       Tempoh menunggu dos penggalak bagi penerima do...
# 2       Melihat cara kerajaan mahupun pembangkang meny...
# 3       Penatlah dapat sorang menteri perasan cantik n...
# 4       Apakah produk Apple yang berjaya anda miliki p...
# ...                                                   ...
# 152262  @SyedSaddiq Abah kau yg plan semua ni sadiq. T...
# ...

# %%
df_merged2 = df_merged[df_merged['sentiment_label'] != 'Neutral']

# %%
num_rows = len(df_merged2)
print("Number of rows remaining: ", num_rows)
# Out:
# Number of rows remaining:  76587

# %%
df_merged2.to_csv("3 VADERphase.csv")

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# Initialize the VADER polarity analyzer
sid = SentimentIntensityAnalyzer()

# Analyze text as a whole
text = "I have trust issue problem"
whole_analysis = sid.polarity_scores(text)
print("Whole Text Analysis:")
print(whole_analysis)

# Analyze text word by word
words = text.split()
word_by_word_analysis = []

for word in words:
    word_analysis = sid.polarity_scores(word)
    word_by_word_analysis.append((word, word_analysis))

print("\nWord-by-Word Analysis:")
for word, analysis in word_by_word_analysis:
    print(f"Word: {word}\tAnalysis: {analysis}")
# Out:
# Whole Text Analysis:
# {'neg': 0.3, 'neu': 0.333, 'pos': 0.367, 'compound': 0.1531}
#
# Word-by-Word Analysis:
# Word: II	Analysis: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Word: have	Analysis: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Word: trust	Analysis: {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.5106}
# Word: issue	Analysis: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Word: problem	Analysis: {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.4019}
