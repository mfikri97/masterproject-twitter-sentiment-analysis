# %%
import pandas as pd

# %%
#df_merged = pd.read_csv("ScrapingPhase.csv")
df_merged = pd.read_csv("Therest.csv")
df_merged2 = pd.read_csv("EntertainerandpoliticsPost.csv")

# %%
print(df_merged['Text'].head())
# Out:
# 0    Menanti dengan penuh sabar, terdetik untuk mel...
# 1    Empat kali pembayaran sahaja lagi untuk saya k...
# 2    iPhone paling releven dibeli tahun 2022\n\niPh...
# 3    Aplikasi ⁦@my_sejahtera⁩ sedia untuk dikemaski...
# 4    Mungkin kita perlu bantuan @CFM_Malaysia untuk...
# Name: Text, dtype: object

# %%
import time

def malay_to_english(malay_word):
    complete_word = get_complete_word(malay_word)
    time.sleep(0.2)  # Add a 0.5-second pause before translating
    english_word = translate_word(complete_word)
    return english_word

# %%
df_first_half = df_merged.iloc[:len(df_merged)//2]
df_second_half = df_merged.iloc[len(df_merged)//2:]

# %%
import numpy as np

# Split the second half of the dataframe into 5 parts
df_first_half_parts = np.array_split(df_first_half, 10)

# Assign each part to a new dataframe
df_firsthalf_part1 = df_first_half_parts[0]
df_firsthalf_part2 = df_first_half_parts[1]
df_firsthalf_part3 = df_first_half_parts[2]
df_firsthalf_part4 = df_first_half_parts[3]
df_firsthalf_part5 = df_first_half_parts[4]
df_firsthalf_part6 = df_first_half_parts[5]
df_firsthalf_part7 = df_first_half_parts[6]
df_firsthalf_part8 = df_first_half_parts[7]
df_firsthalf_part9 = df_first_half_parts[8]
df_firsthalf_part10 = df_first_half_parts[9]

# %%
import numpy as np

# Split the second half of the dataframe into 5 parts
df_second_half_parts = np.array_split(df_second_half, 5)

# Assign each part to a new dataframe
df_second_half_part1 = df_second_half_parts[0]
df_second_half_part2 = df_second_half_parts[1]
df_second_half_part3 = df_second_half_parts[2]
df_second_half_part4 = df_second_half_parts[3]
df_second_half_part5 = df_second_half_parts[4]

# %%
import numpy as np

# Split the second half of the dataframe into 5 parts
df2_parts = np.array_split(df_merged2, 10)

# Assign each part to a new dataframe
df2_part1 = df2_parts[0]
df2_part2 = df2_parts[1]
df2_part3 = df2_parts[2]
df2_part4 = df2_parts[3]
df2_part5 = df2_parts[4]
df2_part6 = df2_parts[5]
df2_part7 = df2_parts[6]
df2_part8 = df2_parts[7]
df2_part9 = df2_parts[8]
df2_part10 = df2_parts[9]

# %%
# Apply the function on the sec half part 1
df_firsthalf_part1["Translated Text"] = df_firsthalf_part1["Text"].apply(malay_to_english)
df_firsthalf_part1.to_csv("df_firsthalf_part1.csv",index= False)

# %%
# Apply the function on the sec half part 2
df_firsthalf_part2["Translated Text"] = df_firsthalf_part2["Text"].apply(malay_to_english)
df_firsthalf_part2.to_csv("df_firsthalf_part2.csv",index= False)

# %%
# Apply the function on the sec half part 2
df_firsthalf_part3["Translated Text"] = df_firsthalf_part3["Text"].apply(malay_to_english)
df_firsthalf_part3.to_csv("df_firsthalf_part3.csv",index= False)

# %%
# Apply the function on the sec half part 2
df_firsthalf_part4["Translated Text"] = df_firsthalf_part4["Text"].apply(malay_to_english)
df_firsthalf_part4.to_csv("df_firsthalf_part4.csv",index= False)

# %%
# Apply the function on the sec half part 2
df_firsthalf_part5["Translated Text"] = df_firsthalf_part5["Text"].apply(malay_to_english)
df_firsthalf_part5.to_csv("df_firsthalf_part5.csv",index= False)

# %%
# Apply the function on the sec half part 2
df_firsthalf_part6["Translated Text"] = df_firsthalf_part6["Text"].apply(malay_to_english)
df_firsthalf_part6.to_csv("df_firsthalf_part6.csv",index= False)

# %%
# Apply the function on the sec half part 2
df_firsthalf_part7["Translated Text"] = df_firsthalf_part7["Text"].apply(malay_to_english)
df_firsthalf_part7.to_csv("df_firsthalf_part7.csv",index= False)

# %%
# Apply the function on the sec half part 2
df_firsthalf_part8["Translated Text"] = df_firsthalf_part8["Text"].apply(malay_to_english)
df_firsthalf_part8.to_csv("df_firsthalf_part8.csv",index= False)

# %%
# Apply the function on the sec half part 2
df_firsthalf_part9["Translated Text"] = df_firsthalf_part9["Text"].apply(malay_to_english)
df_firsthalf_part9.to_csv("df_firsthalf_part9.csv",index= False)

# %%
# Apply the function on the sec half part 2
df_firsthalf_part10["Translated Text"] = df_firsthalf_part10["Text"].apply(malay_to_english)
df_firsthalf_part10.to_csv("df_firsthalf_part10.csv",index= False)

# %%
# Apply the function on the sec half part 1
df_second_half_part1["Translated Text"] = df_second_half_part1["Text"].apply(malay_to_english)

# %%
df_second_half_part1
# Out:
#               Username                                               Text  \
# 55576  CreatedCreatorr                 @khairulaming S3 Business thread 👆
# 55577       hanahunnyy  @khairulaming thank you for sharing. we need m...
# 55578       kd65453672                           @khairulaming Mantappp 🔥
# 55579      ayosurprise      @khairulaming nice sharing. thank you so much
# 55580       ohmakguard  @khairulaming jarang la thread KA ni tak berma...
# ...                ...                                                ...
# 66687        31tahanyy  @khairulaming bolela dengan moto😏 https://t.co...
# 66688      hydesign_my           @khairulaming Tak sahur ke harini miming
# 66689            Fiq1_  @khairulaming Paling suka parallel park sbb bi...
# 66690         NurulWHB  @khairulaming I admire you!  Semoga terus berj...
# 66691         FWWBirch  @khairulaming Bab parking ni, saya mahir. Insy...
#
#                     Date Created  Number of Likes  Number of Retweet  \
# ...

# %%
# Apply the function on the sec half part 2
df_second_half_part2["Translated Text"] = df_second_half_part2["Text"].apply(malay_to_english)

# %%
# Apply the function on the sec half part 2
df_second_half_part3["Translated Text"] = df_second_half_part3["Text"].apply(malay_to_english)

# %%
# Apply the function on the sec half part 2
df_second_half_part4["Translated Text"] = df_second_half_part4["Text"].apply(malay_to_english)

# %%
# Apply the function on the sec half part 2
df_second_half_part5["Translated Text"] = df_second_half_part5["Text"].apply(malay_to_english)

# %%
# Apply the function on the sec half part 1
df2_part1["Translated Text"] = df2_part1["Text"].apply(malay_to_english)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [18], line 2
#       1 # Apply the function on the sec half part 1
# ----> 2 df2_part1["Translated Text"] = df2_part1["Text"].apply(malay_to_english)
#
# File c:\Users\Fikri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\Fikri\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\apply.py:1105, in SeriesApply.apply(self)
# ...

# %%
# Apply the function on the sec half part 1
df2_part2["Translated Text"] = df2_part2["Text"].apply(malay_to_english)

# %%
# Apply the function on the sec half part 1
df2_part3["Translated Text"] = df2_part3["Text"].apply(malay_to_english)

# %%
df2_part3.to_csv("df2_part3.csv",index= False)

# %%
# Apply the function on the sec half part 1
df2_part4["Translated Text"] = df2_part4["Text"].apply(malay_to_english)

# %%
df2_part4.to_csv("df2_part4.csv",index= False)

# %%
# Apply the function on the sec half part 1
df2_part5["Translated Text"] = df2_part5["Text"].apply(malay_to_english)

# %%
df2_part5.to_csv("df2_part5.csv",index= False)

# %%
# Apply the function on the sec half part 1
df2_part6["Translated Text"] = df2_part6["Text"].apply(malay_to_english)

# %%
df2_part6.to_csv("df2_part6.csv",index= False)

# %%
# Apply the function on the sec half part 1
df2_part7["Translated Text"] = df2_part7["Text"].apply(malay_to_english)

# %%
df2_part7.to_csv("df2_part7.csv",index= False)

# %%
# Apply the function on the sec half part 1
df2_part8["Translated Text"] = df2_part8["Text"].apply(malay_to_english)

# %%
df2_part8.to_csv("df2_part8.csv",index= False)

# %%
# Apply the function on the sec half part 1
df2_part9["Translated Text"] = df2_part9["Text"].apply(malay_to_english)

# %%
df2_part9.to_csv("df2_part9.csv",index= False)

# %%
# Apply the function on the sec half part 1
df2_part10["Translated Text"] = df2_part10["Text"].apply(malay_to_english)

# %%
df2_part10.to_csv("df2_part10.csv",index= False)

# %%
# Apply the function on the sec half part 1
df2_part1["Translated Text"] = df2_part1["Text"].apply(malay_to_english)

# %%
df2_part1.to_csv("df2_part1.csv",index= False)

# %%
combined_df1 = pd.concat([df_first_half,df_second_half_part1,df_second_half_part2,df_second_half_part3,df_second_half_part4,df_second_half_part5, df2_part1, df2_part2, df2_part3,df2_part4,df2_part5,df2_part6,df2_part7,df2_part8,df2_part9,df2_part10], axis = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [27], line 1
# ----> 1 combined_df1 = pd.concat([df_first_half,df_second_half_part1,df_second_half_part2,df_second_half_part3,df_second_half_part4,df_second_half_part5, df2_part1, df2_part2, df2_part3,df2_part4,df2_part5,df2_part6,df2_part7,df2_part8,df2_part9,df2_part10], axis = 0)
#
# NameError: name 'df_first_half' is not defined

# %%
#df_merged = pd.read_csv("ScrapingPhase.csv")
combined_df1 = pd.read_csv("2.1 CleanedPhase.csv")

# %%
combined_cleaned = pd.concat([combined_df1, df2_part1, df2_part2, df2_part3,df2_part4,df2_part5,df2_part6,df2_part7,df2_part8,df2_part9,df2_part10], axis = 0)
combined_cleaned
# Out:
#                Username                                               Text  \
# 0            XavierNaxa  Menanti dengan penuh sabar, terdetik untuk mel...
# 1            XavierNaxa  Empat kali pembayaran sahaja lagi untuk saya k...
# 2            XavierNaxa  iPhone paling releven dibeli tahun 2022\n\niPh...
# 3            XavierNaxa  Aplikasi ⁦@my_sejahtera⁩ sedia untuk dikemaski...
# 4            XavierNaxa  Mungkin kita perlu bantuan @CFM_Malaysia untuk...
# ...                 ...                                                ...
# 141485       SyedSaddiq                                                  😍
# 141486    neyrashazeyra  @SyedSaddiq 🤣😜🤭 rm7 per pair. I think I bought...
# 141487  sharifahbadriy1                                    @SyedSaddiq 🤣🤣🤣
# 141488   WilliamChua007  @SyedSaddiq Adakah sarung kaki dalam gambar it...
# 141489        chitra_ng                    @SyedSaddiq These are so cute 😍
#
# ...

# %%
combined_cleaned.duplicated().value_counts()
# Out:
# False    252642
# dtype: int64

# %%
combined_cleaned.to_csv("combined1.csv",index= False)

# %%
import re
from nltk.corpus import stopwords
import nltk

#remove stopwords
def remove_stopwords(text):
    text = ' '.join([word for word in text.split() if word not in (stopwords.words('english'))])
    return text

#remove newline
def remove_newline(text):
    text = text.replace('\n', ' ')
    return text
    
# Remove url  
def remove_url(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'',text)

# Remove punctuation
def remove_punct(text):
    table = str.maketrans('', '', string.punctuation)
    return text.translate(table)

# Remove html 
def remove_html(text):
    html=re.compile(r'<.*?>')
    return html.sub(r'',text)

# Remove @username
def remove_username(text):
    return re.sub('@[^\s]+','',text)


# Decontraction text
def decontraction(text):
    text = re.sub(r"won\'t", " will not", text)
    text = re.sub(r"won\'t've", " will not have", text)
    text = re.sub(r"can\'t", " can not", text)
    text = re.sub(r"don\'t", " do not", text)
    
    text = re.sub(r"can\'t've", " can not have", text)
    text = re.sub(r"ma\'am", " madam", text)
    text = re.sub(r"let\'s", " let us", text)
    text = re.sub(r"ain\'t", " am not", text)
    text = re.sub(r"shan\'t", " shall not", text)
    text = re.sub(r"sha\n't", " shall not", text)
    text = re.sub(r"o\'clock", " of the clock", text)
    text = re.sub(r"y\'all", " you all", text)
    text = re.sub(r"n\'t", " not", text)
    text = re.sub(r"n\'t've", " not have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'s", " is", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'d've", " would have", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ll've", " will have", text)
    text = re.sub(r"\'t", " not", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'m", " am", text)
    text = re.sub(r"\'re", " are", text)
    return text  

# Seperate alphanumeric
def seperate_alphanumeric(text):
    words = text
    words = re.findall(r"[^\W\d_]+|\d+", words)
    return " ".join(words)

def cont_rep_char(text):
    tchr = text.group(0) 
    
    if len(tchr) > 1:
        return tchr[0:2] 



def char(text):
    substitute = re.sub(r'[^a-zA-Z]',' ',text)
    return substitute




# Apply functions on tweets
#df_merged['final_text'] = df_merged['Text']

#for func in [remove_username, remove_newline, remove_url, decontraction, seperate_alphanumeric, unique_char, char, lambda x: x.lower(), remove_stopwords]:
#    combined_cleaned['Translated Cleaned Text'] = combined_cleaned['Translated Text'].apply(func)

# %%
# Convert float values in "Translated Text" column to empty string
combined_cleaned["Translated Text"] = combined_cleaned["Translated Text"].apply(lambda x: "" if isinstance(x, float) else x)

# Apply cleaning functions on "Translated Text"
for func in [remove_username, remove_newline, remove_url, decontraction, seperate_alphanumeric, unique_char, char, lambda x: x.lower(), remove_stopwords]:
    combined_cleaned['Translated Cleaned Text'] = combined_cleaned['Translated Text'][:100].apply(func)
# Out:
# C:\Users\Fikri\AppData\Local\Temp\ipykernel_17656\2818885084.py:6: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   combined_cleaned['Translated Cleaned Text'] = combined_cleaned['Translated Text'][:100].apply(func)

# %%
combined_cleaned.head(50)
# Out:
#       Username                                               Text  \
# 0   XavierNaxa  Menanti dengan penuh sabar, terdetik untuk mel...
# 1   XavierNaxa  Empat kali pembayaran sahaja lagi untuk saya k...
# 2   XavierNaxa  iPhone paling releven dibeli tahun 2022\n\niPh...
# 3   XavierNaxa  Aplikasi ⁦@my_sejahtera⁩ sedia untuk dikemaski...
# 4   XavierNaxa  Mungkin kita perlu bantuan @CFM_Malaysia untuk...
# 5   XavierNaxa  Saya sangat berharap Apple mula melakukan tran...
# 6   XavierNaxa  Tahukah anda, Steve Jobs pernah menyatakan unt...
# 7   XavierNaxa  iPhone 6 Plus dikhabarkan akan diisytiharkan s...
# 8   XavierNaxa  Beats Studio Buds dan AirTag edisi khas mula d...
# 9   XavierNaxa  Selamat menggunakan watchOS https://t.co/DgOac...
# 10  XavierNaxa  iPad yang diperkasa dengan cip A12 Bionic dan ...
# 11  XavierNaxa  Tiada masalah untuk guna MagSafe, cuma model i...
# 12  XavierNaxa  Adakah anda bersedia dan menerima sekiranya Ap...
# ...

# %%
combined_cleaned.to_csv("combined1.csv",index= False)

# %%
df_merged
# Out:
#               Username                                               Text  \
# 0           XavierNaxa  Menanti dengan penuh sabar, terdetik untuk mel...
# 1           XavierNaxa  Empat kali pembayaran sahaja lagi untuk saya k...
# 2           XavierNaxa  iPhone paling releven dibeli tahun 2022\n\niPh...
# 3           XavierNaxa  Aplikasi ⁦@my_sejahtera⁩ sedia untuk dikemaski...
# 4           XavierNaxa  Mungkin kita perlu bantuan @CFM_Malaysia untuk...
# ...                ...                                                ...
# 111147   RosaBellaluna  @DrAmalinaBakri Did you take pfizer? How long ...
# 111148     elamjamal84            @DrAmalinaBakri https://t.co/VsQ5oKoWO3
# 111149        gibaok25  @DrAmalinaBakri What is the concept of vaccine...
# 111150  mandarinclass_               @DrAmalinaBakri Happy new year Dr!!!
# 111151       TuanZul93              @DrAmalinaBakri Stay safe and healthy
#
#                      Date Created  Number of Likes  Number of Retweet  \
# ...

# %%
# Save the DataFrame to a CSV file
df_merged.to_csv('2 CleanedPhase.csv', index=False)

# %%
# Save the DataFrame to a CSV file
combined_df1.to_csv('2.1 CleanedPhase.csv', index=False)

# %%
df2_part2.to_csv("df2_part2.csv",index= False)

# %%
#Combine first part , df1
first_df = pd.concat([df_firsthalf_part1,df_firsthalf_part2,df_firsthalf_part3,df_firsthalf_part4,df_firsthalf_part5,df_firsthalf_part6,df_firsthalf_part7,df_firsthalf_part8,df_firsthalf_part9,df_firsthalf_part10])
first_df.to_csv("combined first df.csv",index= False)

# %%
#second part df 1
second_df = pd.concat([df_second_half_part1,df_second_half_part2,df_second_half_part3,df_second_half_part4,df_second_half_part5])

# %%
second_df = pd.read_csv('second_df1.csv', encoding='iso-8859-1')
second_df
second_df = second_df.dropna()
second_df
# Out:
# C:\Users\Fikri\AppData\Local\Temp\ipykernel_12540\2039773918.py:1: DtypeWarning: Columns (0,1,2,6,9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   second_df = pd.read_csv('second_df1.csv', encoding='iso-8859-1')

# %%
first_df
# Out:
#             Username                                               Text  \
# 0         XavierNaxa  Menanti dengan penuh sabar, terdetik untuk mel...
# 1         XavierNaxa  Empat kali pembayaran sahaja lagi untuk saya k...
# 2         XavierNaxa  iPhone paling releven dibeli tahun 2022\n\niPh...
# 3         XavierNaxa  Aplikasi ⁦@my_sejahtera⁩ sedia untuk dikemaski...
# 4         XavierNaxa  Mungkin kita perlu bantuan @CFM_Malaysia untuk...
# ...              ...                                                ...
# 55571   Januarhaikal               @khairulaming You are such an idol 🥺
# 55572  MUHAMMADAIDI1                               @khairulaming Mantap
# 55573   AinulNunanaa                           @khairulaming Love this!
# 55574       captfaiq     @khairulaming Good sharing! Thank you aming 🙌🏻
# 55575      emyamidis                  @khairulaming Wahh so amazing! 👏🏽
#
#                     Date Created  Number of Likes  Number of Retweet  \
# ...

# %%
combined_cleaned.to_csv("combined1.csv",index= False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Fikri\Downloads\CODING TWITTER PROJECT\1.0 CLEANING.ipynb Cell 64 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Fikri/Downloads/CODING%20TWITTER%20PROJECT/1.0%20CLEANING.ipynb#Y120sZmlsZQ%3D%3D?line=0'>1</a> combined_cleaned.to_csv("combined1.csv",index= False)
#
# NameError: name 'combined_cleaned' is not defined

# %%
#df 2
df2_part1 = pd.read_csv('df2_part1.csv')
df2_part2 = pd.read_csv('df2_part2.csv')
df2_part3 = pd.read_csv('df2_part3.csv')
df2_part4 = pd.read_csv('df2_part4.csv')
df2_part5 = pd.read_csv('df2_part5.csv')
df2_part6 = pd.read_csv('df2_part6.csv')
df2_part7 = pd.read_csv('df2_part7.csv')
df2_part8 = pd.read_csv('df2_part8.csv')
df2_part9= pd.read_csv('df2_part9.csv')
df2_part10 = pd.read_csv('df2_part10.csv')
df2 = pd.concat([df2_part1,df2_part2,df2_part3,df2_part4,df2_part5,df2_part6,df2_part7,df2_part8,df2_part9,df2_part10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Fikri\Downloads\CODING TWITTER PROJECT\1.0 CLEANING.ipynb Cell 65 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Fikri/Downloads/CODING%20TWITTER%20PROJECT/1.0%20CLEANING.ipynb#Y121sZmlsZQ%3D%3D?line=0'>1</a> #df 2
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Fikri/Downloads/CODING%20TWITTER%20PROJECT/1.0%20CLEANING.ipynb#Y121sZmlsZQ%3D%3D?line=1'>2</a> df2_part1 = pd.read_csv('df2_part1.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/Fikri/Downloads/CODING%20TWITTER%20PROJECT/1.0%20CLEANING.ipynb#Y121sZmlsZQ%3D%3D?line=2'>3</a> df2_part2 = pd.read_csv('df2_part2.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/Fikri/Downloads/CODING%20TWITTER%20PROJECT/1.0%20CLEANING.ipynb#Y121sZmlsZQ%3D%3D?line=3'>4</a> df2_part3 = pd.read_csv('df2_part3.csv')
#
# NameError: name 'pd' is not defined

# %%
df2
# Out:
#               Username                                               Text  \
# 0            sofyank96  Spiderman No More Spoiler https://t.co/OdrdmJ85YO
# 1            sofyank96  Allahuakbar.. salam takziah buat keluarga mang...
# 2            sofyank96  Pip pippppp... kereta nak lalu 🚗 https://t.co/...
# 3            sofyank96  Buat masa skrg, kpd peminat spiderman, sy reko...
# 4            sofyank96  Eventhough it's only 2 seconds of the scene, b...
# ...                ...                                                ...
# 14144       SyedSaddiq                                                  😍
# 14145    neyrashazeyra  @SyedSaddiq 🤣😜🤭 rm7 per pair. I think I bought...
# 14146  sharifahbadriy1                                    @SyedSaddiq 🤣🤣🤣
# 14147   WilliamChua007  @SyedSaddiq Adakah sarung kaki dalam gambar it...
# 14148        chitra_ng                    @SyedSaddiq These are so cute 😍
#
#                     Date Created  Number of Likes  Number of Retweet  \
# ...

# %%
all_rows=pd.concat([first_df,second_df,df2])

# %%
all_rows
# Out:
#               Username                                               Text  \
# 0           XavierNaxa  Menanti dengan penuh sabar, terdetik untuk mel...
# 1           XavierNaxa  Empat kali pembayaran sahaja lagi untuk saya k...
# 2           XavierNaxa  iPhone paling releven dibeli tahun 2022\n\niPh...
# 3           XavierNaxa  Aplikasi ⁦@my_sejahtera⁩ sedia untuk dikemaski...
# 4           XavierNaxa  Mungkin kita perlu bantuan @CFM_Malaysia untuk...
# ...                ...                                                ...
# 14144       SyedSaddiq                                                  😍
# 14145    neyrashazeyra  @SyedSaddiq 🤣😜🤭 rm7 per pair. I think I bought...
# 14146  sharifahbadriy1                                    @SyedSaddiq 🤣🤣🤣
# 14147   WilliamChua007  @SyedSaddiq Adakah sarung kaki dalam gambar it...
# 14148        chitra_ng                    @SyedSaddiq These are so cute 😍
#
#                     Date Created  Number of Likes  Number of Retweet  \
# ...

# %%
all_rows.isnull().sum()
# Out:
# Username             0
# Text                 0
# Date Created         0
# Number of Likes      0
# Number of Retweet    0
# Number of Replies    0
# Source of Tweet      0
# User ID              0
# Conversation ID      0
# status               0
# Category             0
# Translated Text      0
# dtype: int64

# %%
test = "Maybe we need the help of @CFM_Malaysia to bri..."

# %%
# Convert float values in "Translated Text" column to empty string
#all_rows["Translated Text"] = all_rows["Translated Text"].apply(lambda x: "" if isinstance(x, float) else x)

# Apply cleaning functions on "Translated Text"
cleaned_text = all_rows['Translated Text']
for func in [remove_username, remove_newline, remove_url, decontraction, seperate_alphanumeric, char, remove_stopwords, lambda x: x.lower()]:
    cleaned_text = cleaned_text.apply(func)
all_rows['Translated Cleaned Text'] = cleaned_text

# %%
all_rows
# Out:
#               Username                                               Text  \
# 0           XavierNaxa  Menanti dengan penuh sabar, terdetik untuk mel...
# 1           XavierNaxa  Empat kali pembayaran sahaja lagi untuk saya k...
# 2           XavierNaxa  iPhone paling releven dibeli tahun 2022\n\niPh...
# 3           XavierNaxa  Aplikasi ⁦@my_sejahtera⁩ sedia untuk dikemaski...
# 4           XavierNaxa  Mungkin kita perlu bantuan @CFM_Malaysia untuk...
# ...                ...                                                ...
# 14144       SyedSaddiq                                                  😍
# 14145    neyrashazeyra  @SyedSaddiq 🤣😜🤭 rm7 per pair. I think I bought...
# 14146  sharifahbadriy1                                    @SyedSaddiq 🤣🤣🤣
# 14147   WilliamChua007  @SyedSaddiq Adakah sarung kaki dalam gambar it...
# 14148        chitra_ng                    @SyedSaddiq These are so cute 😍
#
#                     Date Created  Number of Likes  Number of Retweet  \
# ...

# %%
import pandas as pd
df = pd.read_csv("1.0 Cleaning Output.csv")
df
# Out:
#         Unnamed: 0.1  Unnamed: 0        Username  \
# 0                  0        7856  AzizNorzali_PG
# 1                  1        7858        _riffiez
# 2                  2        7860      sarahsslyn
# 3                  3        7862   farahnadeera_
# 4                  4        7864    hasreypriady
# ...              ...         ...             ...
# 115106        115106       10900      SyedSaddiq
# 115107        115107       11142      SyedSaddiq
# 115108        115108       11445      SyedSaddiq
# 115109        115109       13337      SyedSaddiq
# 115110        115110       13770      SyedSaddiq
#
#                                                      Text  \
# 0       @XavierNaxa Berapa lama purata IPhone boleh di...
# 1       @XavierNaxa Yg tak relevan tu dah boleh buat s...
# 2       @XavierNaxa @XavierNaxa min kenapa iphone 11 s...
# 3       @XavierNaxa Got mine in pink lepas my ipX asyi...
# 4                      @XavierNaxa Ok, nak beli iphone 11
# ...

# %%
repliesdistribution = df["Number of Replies"].median()

# %%
import matplotlib.pyplot as plt

# Get the number of replies per main post
replies_per_main_post = df[df['Conversation ID'] == df['User ID']].groupby('Conversation ID').size()

# Create a histogram of the number of replies per main post
plt.hist(replies_per_main_post, bins=20, range=(0, 100))
plt.title('Distribution of number of replies per main post')
plt.xlabel('Number of replies')
plt.ylabel('Count')
plt.show()

# %%
# Filter the rows where the "status" column has a value of "Main post" and the "Number of Replies" column has a value greater than or equal to 50
new_df = df[(df['status'] == 'Main post') & (df['Number of Replies'] >= 50)]

# Get the list of conversation IDs from new_df
conversation_ids = new_df['Conversation ID'].unique()

# Filter the rows where the "status" column has a value of "reply" and the "Conversation ID" column can be found in conversation_ids
new_df_reply = df[(df['status'] == 'reply') & (df['Conversation ID'].isin(conversation_ids))]

# Group the new_df_reply DataFrame by Conversation ID and count the number of rows in each group, and sort it in descending order
new_df_reply_sorted = new_df_reply.groupby('Conversation ID').size().sort_values(ascending=False).reset_index(name='Count')

# %%
# Get the list of usernames from new_df
usernames = new_df['Username'].unique()

# Filter the rows where the "status" column has a value of "reply" and the "Conversation ID" column can be found in conversation_ids,
# and where the "Username" column is not in the list of usernames
new_df_reply_filtered = new_df_reply[(new_df_reply['status'] == 'reply') &
                                     (new_df_reply['Conversation ID'].isin(conversation_ids)) &
                                     (~new_df_reply['Username'].isin(usernames))]

# Group the new_df_reply_filtered DataFrame by Conversation ID and count the number of rows in each group, and sort it in descending order
new_df_reply_filtered_sorted = new_df_reply_filtered.groupby('Conversation ID').size().sort_values(ascending=False).reset_index(name='Count')

# %%
new_df_reply_filtered
# Out:
#         Unnamed: 0.1  Unnamed: 0         Username  \
# 0                  0        7856   AzizNorzali_PG
# 1                  1        7858         _riffiez
# 2                  2        7860       sarahsslyn
# 3                  3        7862    farahnadeera_
# 4                  4        7864     hasreypriady
# ...              ...         ...              ...
# 113320        113320       14048         amirapis
# 113321        113321       14049         Mrzach17
# 113322        113322       14050         Mrzach17
# 113323        113323       14051  Belalan60727537
# 113324        113324       14052         BBengtvz
#
#                                                      Text  \
# 0       @XavierNaxa Berapa lama purata IPhone boleh di...
# 1       @XavierNaxa Yg tak relevan tu dah boleh buat s...
# 2       @XavierNaxa @XavierNaxa min kenapa iphone 11 s...
# 3       @XavierNaxa Got mine in pink lepas my ipX asyi...
# 4                      @XavierNaxa Ok, nak beli iphone 11
# ...

# %%
# Combine the new_df_reply_filtered and new_df dataframes
combined_df = pd.concat([new_df_reply_filtered, new_df], ignore_index=True)

# Print the combined dataframe
combined_df
# Out:
#         Unnamed: 0.1  Unnamed: 0        Username  \
# 0                  0        7856  AzizNorzali_PG
# 1                  1        7858        _riffiez
# 2                  2        7860      sarahsslyn
# 3                  3        7862   farahnadeera_
# 4                  4        7864    hasreypriady
# ...              ...         ...             ...
# 115106        115106       10900      SyedSaddiq
# 115107        115107       11142      SyedSaddiq
# 115108        115108       11445      SyedSaddiq
# 115109        115109       13337      SyedSaddiq
# 115110        115110       13770      SyedSaddiq
#
#                                                      Text  \
# 0       @XavierNaxa Berapa lama purata IPhone boleh di...
# 1       @XavierNaxa Yg tak relevan tu dah boleh buat s...
# 2       @XavierNaxa @XavierNaxa min kenapa iphone 11 s...
# 3       @XavierNaxa Got mine in pink lepas my ipX asyi...
# 4                      @XavierNaxa Ok, nak beli iphone 11
# ...

# %%
import nltk
from nltk.corpus import stopwords

stops = set(stopwords.words('english'))

word_list = ["0o", "0s", "3a", "3b", "3d", "6b", "6o", "a", "a1", "a2", "a3", "a4", "ab", "able", "about", "above", "abst", "ac", "accordance", "according", "accordingly", "across", "act", "actually", "ad", "added", "adj", "ae", "af", "affected", "affecting", "affects", "after", "afterwards", "ag", "again", "against", "ah", "ain", "ain't", "aj", "al", "all", "allow", "allows", "almost", "alone", "along", "already", "also", "although", "
any','are','as','at','be','because','been','but','by','can','cannot','could','dear','did','do','does','either','else','ever','every','for','from','get','got','had','has','have','he','her','hers','him','his','how','however','i','if','in','into','is','it','its','just','least','let','like','likely','may','me','might','most','must','my','neither','no','nor','not','of','off','often','on','only','or','other','our','own','rather','said','say','says','she','should','since','so','some','than','that','the','their','them','then','there','these','they','this','tis','to','too','twas','us','wants','was','we','were','what','when','where','which','while','who','whom','why','will','with','would','yet','you','your']

for word in word_list:
    if word not in stops:
        stops.add(word)

print(sorted(stops))
# Out:
# ['0o', '0s', '3a', '3b', '3d', '6b', '6o', 'a', "a's", 'a1', 'a2', 'a3', 'a4', 'ab', 'able', 'about', 'above', 'abst', 'ac', 'accordance', 'according', 'accordingly', 'across', 'act', 'actually', 'ad', 'added', 'adj', 'ae', 'af', 'affected', 'affecting', 'affects', 'after', 'afterwards', 'ag', 'again', 'against', 'ah', 'ain', "ain't", 'aj', 'al', 'all', 'allow', 'allows', 'almost', 'alone', 'along', 'already', 'also', 'although', 'always', 'am', 'among', 'amongst', 'amoungst', 'amount', 'amp', 'an', 'and', 'announce', 'another', 'any', 'anybody', 'anyhow', 'anymore', 'anyone', 'anything', 'anyway', 'anyways', 'anywhere', 'ao', 'ap', 'apart', 'apparently', 'appear', 'appreciate', 'appropriate', 'approximately', 'ar', 'are', 'aren', "aren't", 'arent', 'arise', 'around', 'as', 'aside', 'ask', 'asking', 'associated', 'at', 'au', 'auth', 'av', 'available', 'aw', 'away', 'awfully', 'ax', 'ay', 'az', 'b', 'b1', 'b2', 'b3', 'ba', 'back', 'bc', 'bd', 'be', 'became', 'because', 'become', 'beco
# ...

# %%
# Define a function to remove stopwords from a text string
def remove_stopwords(text):
    if isinstance(text, str):
        words = text.split()
        filtered_words = [word for word in words if word.lower() not in stops]
        return ' '.join(filtered_words)
    else:
        return text

# %%
# Apply the remove_stopwords function to the Translated Cleaned Text column
combined_df['Translated Cleaned Text'] = combined_df['Translated Cleaned Text'].apply(remove_stopwords)

# %%
for text in combined_df['Translated Cleaned Text']:
    if isinstance(text, str) and "amp" in text:
        print(text)
# Out:
# broken vote campaign time history corrupt votes dominate spoiled votes masani
# pampers child
# buy shopee scam wrote minimum free shipping checkout free shipping voucher code hahahahaha hampeh
# pukimak gimampuss commented malay language class
# bushel stamp
# satu sampailapapan
# politicians busy campaigning hahah worry agong wrong people marhaen
# closed crawled buy son pampers milk boy months feels difficulties gov
# time hampir gila dengan kurungan people lives
# time nampak min hahaha
# fun blame government minimum wage issue people families eat bread sleep bridge day pampers banana leaves
# victims admin ruler hampeh betoi
# jamil mampos
# dari graphic music sampai gameplay simple calming adventurous recommended played ipad
# coffee lover tcbtl great min diorg pure vanilla ice blended vanilla iced latte coffee lovers tent camp secmugggg
# battery review listen battery champ stories hahaha
# story damp feel sleepy watched haihhhh time looked
# bro ride bookstore campus
# ...

# %%
combined_df.to_csv("1.0 Cleaning Output.csv")
