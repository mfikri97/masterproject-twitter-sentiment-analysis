# %%
import pandas as pd
import numpy as np

# %%
#df_merged = pd.read_csv("ScrapingPhase.csv")
df_1 = pd.read_csv("Therest.csv")
df_2 = pd.read_csv("EntertainerandpoliticsPost.csv")

# %%
df_all = pd.concat([df_1,df_2])
df_all
# Out:
#                Username                                               Text  \
# 0            XavierNaxa  Menanti dengan penuh sabar, terdetik untuk mel...
# 1            XavierNaxa  Empat kali pembayaran sahaja lagi untuk saya k...
# 2            XavierNaxa  iPhone paling releven dibeli tahun 2022\n\niPh...
# 3            XavierNaxa  Aplikasi ⁦@my_sejahtera⁩ sedia untuk dikemaski...
# 4            XavierNaxa  Mungkin kita perlu bantuan @CFM_Malaysia untuk...
# ...                 ...                                                ...
# 141485       SyedSaddiq                                                  😍
# 141486    neyrashazeyra  @SyedSaddiq 🤣😜🤭 rm7 per pair. I think I bought...
# 141487  sharifahbadriy1                                    @SyedSaddiq 🤣🤣🤣
# 141488   WilliamChua007  @SyedSaddiq Adakah sarung kaki dalam gambar it...
# 141489        chitra_ng                    @SyedSaddiq These are so cute 😍
#
# ...

# %%
# change the data type of the "Date Created" column to datetime
df_all['Date Created'] = pd.to_datetime(df_all['Date Created'])

# change the data type of the "User ID" column to string
df_all['User ID'] =df_all['User ID'].astype(str)

# change the data type of the "Conversation ID" column to int
df_all['Conversation ID'] = df_all['Conversation ID'].astype(str)

# %%
df_all
# Out:
#                Username                                               Text  \
# 0            XavierNaxa  Menanti dengan penuh sabar, terdetik untuk mel...
# 1            XavierNaxa  Empat kali pembayaran sahaja lagi untuk saya k...
# 2            XavierNaxa  iPhone paling releven dibeli tahun 2022\n\niPh...
# 3            XavierNaxa  Aplikasi ⁦@my_sejahtera⁩ sedia untuk dikemaski...
# 4            XavierNaxa  Mungkin kita perlu bantuan @CFM_Malaysia untuk...
# ...                 ...                                                ...
# 141485       SyedSaddiq                                                  😍
# 141486    neyrashazeyra  @SyedSaddiq 🤣😜🤭 rm7 per pair. I think I bought...
# 141487  sharifahbadriy1                                    @SyedSaddiq 🤣🤣🤣
# 141488   WilliamChua007  @SyedSaddiq Adakah sarung kaki dalam gambar it...
# 141489        chitra_ng                    @SyedSaddiq These are so cute 😍
#
# ...

# %%
# split the DataFrame into 15 parts
dfs = np.array_split(df_all, 15)

# assign each part to a new variable
df_part1, df_part2, df_part3, df_part4, df_part5, df_part6, df_part7, df_part8, df_part9, df_part10, df_part11, df_part12, df_part13, df_part14, df_part15 = dfs

# %%
df_part1
# Out:
#              Username                                               Text  \
# 0          XavierNaxa  Menanti dengan penuh sabar, terdetik untuk mel...
# 1          XavierNaxa  Empat kali pembayaran sahaja lagi untuk saya k...
# 2          XavierNaxa  iPhone paling releven dibeli tahun 2022\n\niPh...
# 3          XavierNaxa  Aplikasi ⁦@my_sejahtera⁩ sedia untuk dikemaski...
# 4          XavierNaxa  Mungkin kita perlu bantuan @CFM_Malaysia untuk...
# ...               ...                                                ...
# 16838     luciferdaus                 @fazlihalimmedia Auwoh3 kias rabok
# 16839       alievmore                     @fazlihalimmedia Make sense 😭😭
# 16840  bolehpanggilAL  @fazlihalimmedia Xiaomi mi 11 lite or redmi no...
# 16841       rayzareth  @fazlihalimmedia Case naik satu Hal. Tapi yg l...
# 16842       Akimnazri  @fazlihalimmedia Tk sllu buat esaimen ..to yg ...
#
#                    Date Created  Number of Likes  Number of Retweet  \
# ...

# %%
from deep_translator import GoogleTranslator

def translate_dataframe_column(df, source_col, target_col, source_lang, target_lang):
    """
    Translates the text in a DataFrame column from the source language to the target language
    using Google Translator and stores the translated text in another column.

    Parameters:
    df (pandas.DataFrame): The DataFrame containing the text to be translated.
    source_col (str): The name of the column containing the text to be translated.
    target_col (str): The name of the column to store the translated text.
    source_lang (str): The source language code (e.g. 'en' for English, 'fr' for French).
    target_lang (str): The target language code (e.g. 'en' for English, 'fr' for French).

    Returns:
    pandas.DataFrame: The modified DataFrame with the translated text stored in the target column.
    """
    translator = GoogleTranslator(source=source_lang, target=target_lang)
    df[target_col] = df[source_col].apply(lambda x: translator.translate(x))
    return df

# %%
import pandas as pd
# translate text from 'text' column to 'translated' column
df_part1 = translate_dataframe_column(df_part1, 'Text', 'translated', 'auto', 'en')

# print the translated DataFrame
df_part1.to_csv("df_part1.csv",index= False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\CODING TWITTER PROJECT\1.1 CLEANING.ipynb Cell 9 in 3
#       <a href='vscode-notebook-cell:/d%3A/CODING%20TWITTER%20PROJECT/1.1%20CLEANING.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/d%3A/CODING%20TWITTER%20PROJECT/1.1%20CLEANING.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> # translate text from 'text' column to 'translated' column
# ----> <a href='vscode-notebook-cell:/d%3A/CODING%20TWITTER%20PROJECT/1.1%20CLEANING.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> df_part1 = translate_dataframe_column(df_part1, 'Text', 'translated', 'auto', 'en')
#       <a href='vscode-notebook-cell:/d%3A/CODING%20TWITTER%20PROJECT/1.1%20CLEANING.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> # print the translated DataFrame
# ...

# %%
# translate text from 'text' column to 'translated' column
df_part2 = translate_dataframe_column(df_part2, 'Text', 'translated', 'auto', 'en')

# print the translated DataFrame
df_part2.to_csv("df_part2.csv",index= False)

# %%
# translate text from 'text' column to 'translated' column
df_part3 = translate_dataframe_column(df_part3, 'Text', 'translated', 'auto', 'en')

# print the translated DataFrame
df_part3.to_csv("df_part3.csv",index= False)

# %%
# translate text from 'text' column to 'translated' column
df_part4 = translate_dataframe_column(df_part4, 'Text', 'translated', 'auto', 'en')

# print the translated DataFrame
df_part4.to_csv("df_part4.csv",index= False)

# %%
# translate text from 'text' column to 'translated' column
df_part5 = translate_dataframe_column(df_part5, 'Text', 'translated', 'auto', 'en')

# print the translated DataFrame
df_part5.to_csv("df_part5.csv",index= False)

# %%
# translate text from 'text' column to 'translated' column
df_part6 = translate_dataframe_column(df_part6, 'Text', 'translated', 'auto', 'en')

# print the translated DataFrame
df_part6.to_csv("df_part6.csv",index= False)

# %%
# translate text from 'text' column to 'translated' column
df_part7 = translate_dataframe_column(df_part7, 'Text', 'translated', 'auto', 'en')

# print the translated DataFrame
df_part7.to_csv("df_part7.csv",index= False)

# %%
# translate text from 'text' column to 'translated' column
df_part8 = translate_dataframe_column(df_part8, 'Text', 'translated', 'auto', 'en')

# print the translated DataFrame
df_part8.to_csv("df_part8.csv",index= False)

# %%
# translate text from 'text' column to 'translated' column
df_part9 = translate_dataframe_column(df_part9, 'Text', 'translated', 'auto', 'en')

# print the translated DataFrame
df_part9.to_csv("df_part9.csv",index= False)

# %%
# translate text from 'text' column to 'translated' column
df_part10 = translate_dataframe_column(df_part10, 'Text', 'translated', 'auto', 'en')

# print the translated DataFrame
df_part10.to_csv("df_part10.csv",index= False)

# %%
# translate text from 'text' column to 'translated' column
df_part11 = translate_dataframe_column(df_part11, 'Text', 'translated', 'auto', 'en')

# print the translated DataFrame
df_part11.to_csv("df_part11.csv",index= False)

# %%
# translate text from 'text' column to 'translated' column
df_part12 = translate_dataframe_column(df_part12, 'Text', 'translated', 'auto', 'en')

# print the translated DataFrame
df_part12.to_csv("df_part12.csv",index= False)

# %%
# translate text from 'text' column to 'translated' column
df_part13 = translate_dataframe_column(df_part13, 'Text', 'translated', 'auto', 'en')

# print the translated DataFrame
df_part13.to_csv("df_part13.csv",index= False)

# %%
# translate text from 'text' column to 'translated' column
df_part14 = translate_dataframe_column(df_part14, 'Text', 'translated', 'auto', 'en')

# print the translated DataFrame
df_part14.to_csv("df_part14.csv",index= False)

# %%
# translate text from 'text' column to 'translated' column
df_part15 = translate_dataframe_column(df_part15, 'Text', 'translated', 'auto', 'en')

# print the translated DataFrame
df_part15.to_csv("df_part15.csv",index= False)

# %%
df_all = pd.concat([df_part1, df_part2, df_part3, df_part4, df_part5, df_part6, df_part7, df_part8, df_part9, df_part10, df_part11, df_part12, df_part13, df_part14, df_part15], axis = 0)

# %%
df_all.to_csv("df_all_translated.csv",index= False)

# %%
df_all = pd.read_csv("df_all_translated.csv")

# %%
df_all.duplicated().value_counts()
# Out:
# False    252642
# dtype: int64

# %%
df_all.dropna(inplace=True)

# %%
df_all.isnull().sum()
# Out:
# Username             0
# Text                 0
# Date Created         0
# Number of Likes      0
# Number of Retweet    0
# Number of Replies    0
# Source of Tweet      0
# User ID              0
# Conversation ID      0
# status               0
# Category             0
# translated           0
# dtype: int64

# %%
text = "ThIs Is An ExAmPlE"
output_text = remove_uppercase(text)
print(output_text)  # "hs s n xmpl"
# Out:
# hs s n xml

# %%
import re
from nltk.corpus import stopwords
import nltk

#remove stopwords
def remove_stopwords(text):
    text = ' '.join([word for word in text.split() if word not in (stopwords.words('english'))])
    return text

def convert_to_lowercase(text):
    output_string = ""
    for char in text:
        if char.isupper():
            output_string += char.lower()
        else:
            output_string += char
    return output_string

#remove newline
def remove_newline(text):
    text = text.replace('\n', ' ')
    return text
    
# Remove url  
def remove_url(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'',text)

# Remove punctuation
def remove_punct(text):
    table = str.maketrans('', '', string.punctuation)
    return text.translate(table)


def remove_punct(text):
    return re.sub(r'[^\w\s]', '', text)

# Remove html 
def remove_html(text):
    html=re.compile(r'<.*?>')
    return html.sub(r'',text)


def remove_username(text):
    return re.sub('@[\w]+', '', text)

def remove_stopwords(text):
    if text is None:
        return ""
    else:
        text = ' '.join([word for word in text.split() if word not in (stopwords.words('english'))])
        return text


# Decontraction text
def decontraction(text):
    text = re.sub(r"won\'t", " will not", text)
    text = re.sub(r"won\'t've", " will not have", text)
    text = re.sub(r"can\'t", " can not", text)
    text = re.sub(r"don\'t", " do not", text)
    
    text = re.sub(r"can\'t've", " can not have", text)
    text = re.sub(r"ma\'am", " madam", text)
    text = re.sub(r"let\'s", " let us", text)
    text = re.sub(r"ain\'t", " am not", text)
    text = re.sub(r"shan\'t", " shall not", text)
    text = re.sub(r"sha\n't", " shall not", text)
    text = re.sub(r"o\'clock", " of the clock", text)
    text = re.sub(r"y\'all", " you all", text)
    text = re.sub(r"n\'t", " not", text)
    text = re.sub(r"n\'t've", " not have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'s", " is", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'d've", " would have", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ll've", " will have", text)
    text = re.sub(r"\'t", " not", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'m", " am", text)
    text = re.sub(r"\'re", " are", text)
    return text  

# Seperate alphanumeric
def seperate_alphanumeric(text):
    words = text
    words = re.findall(r"[^\W\d_]+|\d+", words)
    return " ".join(words)

def cont_rep_char(text):
    tchr = text.group(0) 
    
    if len(tchr) > 1:
        return tchr[0:2] 



def char(text):
    substitute = re.sub(r'[^a-zA-Z]',' ',text)
    return substitute




# Apply functions on tweets
#df_merged['final_text'] = df_merged['Text']

#for func in [remove_username, remove_newline, remove_url, decontraction, seperate_alphanumeric, unique_char, char, lambda x: x.lower(), remove_stopwords]:
#    combined_cleaned['Translated Cleaned Text'] = combined_cleaned['Translated Text'].apply(func)

# %%
import string

df_all["translated cleaned"] =df_all["translated"].apply(lambda x: remove_stopwords(x))
df_all["translated cleaned"] =df_all["translated cleaned"].apply(lambda x: convert_to_lowercase(x))
df_all["translated cleaned"] =df_all["translated cleaned"].apply(lambda x: remove_newline(x))
df_all["translated cleaned"] =df_all["translated cleaned"].apply(lambda x: remove_url(x))
df_all["translated cleaned"] =df_all["translated cleaned"].apply(lambda x: remove_html(x))
df_all["translated cleaned"] =df_all["translated cleaned"].apply(lambda x: remove_username(x))
df_all["translated cleaned"] =df_all["translated cleaned"].apply(lambda x: remove_punct(x))
df_all["translated cleaned"] =df_all["translated cleaned"].apply(lambda x: decontraction(x))
df_all["translated cleaned"] =df_all["translated cleaned"].apply(lambda x: seperate_alphanumeric(x))
df_all["translated cleaned"] =df_all["translated cleaned"].apply(lambda x: char(x))

# %%
df_all.isnull().sum()
df_all.head(50)
# Out:
#       Username                                               Text  \
# 0   XavierNaxa  Menanti dengan penuh sabar, terdetik untuk mel...
# 1   XavierNaxa  Empat kali pembayaran sahaja lagi untuk saya k...
# 2   XavierNaxa  iPhone paling releven dibeli tahun 2022\n\niPh...
# 3   XavierNaxa  Aplikasi ⁦@my_sejahtera⁩ sedia untuk dikemaski...
# 4   XavierNaxa  Mungkin kita perlu bantuan @CFM_Malaysia untuk...
# 5   XavierNaxa  Saya sangat berharap Apple mula melakukan tran...
# 6   XavierNaxa  Tahukah anda, Steve Jobs pernah menyatakan unt...
# 7   XavierNaxa  iPhone 6 Plus dikhabarkan akan diisytiharkan s...
# 8   XavierNaxa  Beats Studio Buds dan AirTag edisi khas mula d...
# 9   XavierNaxa  Selamat menggunakan watchOS https://t.co/DgOac...
# 10  XavierNaxa  iPad yang diperkasa dengan cip A12 Bionic dan ...
# 11  XavierNaxa  Tiada masalah untuk guna MagSafe, cuma model i...
# 12  XavierNaxa  Adakah anda bersedia dan menerima sekiranya Ap...
# ...

# %%
# Filter the rows where the "status" column has a value of "Main post" and the "Number of Replies" column has a value greater than or equal to 50
main_post_df = df_all[(df_all['status'] == 'Main post') & (df_all['Number of Replies'] >= 50)]

# Get the list of conversation IDs from new_df
conversation_ids = main_post_df['Conversation ID'].unique()

# Filter the rows where the "status" column has a value of "reply" and the "Conversation ID" column can be found in conversation_ids
df_reply = df_all[(df_all['status'] == 'reply') & (df_all['Conversation ID'].isin(conversation_ids))]

# Group the new_df_reply DataFrame by Conversation ID and count the number of rows in each group, and sort it in descending order
df_reply_sorted = df_reply.groupby('Conversation ID').size().sort_values(ascending=False).reset_index(name='Count')
df_reply_sorted
# Out:
#           Conversation ID  Count
# 0     1422621439048306691    228
# 1     1455865145905745920    218
# 2     1450376657924096004    215
# 3     1432229728383995905    215
# 4     1424901951200796675    210
# ...                   ...    ...
# 1600  1472473815477219330     21
# 1601  1386575743446970374     20
# 1602  1398891080297287681     13
# 1603  1381597542106898437     10
# 1604  1432736383819415553      8
#
# [1605 rows x 2 columns]

# %%
# Get the list of usernames from new_df
usernames = main_post_df['Username'].unique()

# Filter the rows where the "status" column has a value of "reply" and the "Conversation ID" column can be found in conversation_ids,
# and where the "Username" column is not in the list of usernames
df_reply_filtered =df_reply[(df_reply['status'] == 'reply') &
                                     (df_reply['Conversation ID'].isin(conversation_ids)) &
                                     (~df_reply['Username'].isin(usernames))]

# Group the new_df_reply_filtered DataFrame by Conversation ID and count the number of rows in each group, and sort it in descending order
new_df_reply_filtered_groupby =df_reply_filtered.groupby('Conversation ID').size().sort_values(ascending=False).reset_index(name='Count')

# %%
# Combine the new_df_reply_filtered and new_df dataframes
df_all_2 = pd.concat([main_post_df, df_reply_filtered], ignore_index=True)

# Print the combined dataframe
df_all_2
# Out:
#                Username                                               Text  \
# 0            XavierNaxa  iPhone paling releven dibeli tahun 2022\n\niPh...
# 1            XavierNaxa  Tempoh menunggu dos penggalak bagi penerima do...
# 2            XavierNaxa  Melihat cara kerajaan mahupun pembangkang meny...
# 3            XavierNaxa  Penatlah dapat sorang menteri perasan cantik n...
# 4            XavierNaxa  Apakah produk Apple yang berjaya anda miliki p...
# ...                 ...                                                ...
# 152262         amirapis  @SyedSaddiq Abah kau yg plan semua ni sadiq. T...
# 152263         Mrzach17  @SyedSaddiq @EZIARIFFIN Pergi laaaaa tlg rakya...
# 152264         Mrzach17  @SyedSaddiq @EZIARIFFIN Bantuan pun guna duit ...
# 152265  Belalan60727537  @SyedSaddiq isap ganja lg syok🤣🤣 https://t.co/...
# 152266         BBengtvz                            @SyedSaddiq @dyllanor 🔦
#
# ...

# %%
import nltk
from nltk.corpus import stopwords

stops = set(stopwords.words('english'))

word_list = ["0o", "0s", "3a", "3b", "3d", "6b", "6o", "a", "a1", "a2", "a3", "a4", "ab", "able", "about", "above", "abst", "ac", "accordance", "according", "accordingly", "across", "act", "actually", "ad", "added", "adj", "ae", "af", "affected", "affecting", "affects", "after", "afterwards", "ag", "again", "against", "ah", "ain", "ain't", "aj", "al", "all", "allow", "allows", "almost", "alone", "along", "already", "also", "although", "always", "am", "among", "amongst", "amoungst", "amount", "an", "and", "announce", "another", "any", "anybody", "anyhow", "anymore", "anyone", "anything", "anyway", "anyways", "anywhere","amp", "ao", "ap", "apart", "apparently", "appear", "appreciate", "appropriate", "approximately", "ar", "are", "aren", "arent", "aren't", "arise", "around", "as", "a's", "aside", "ask", "asking", "associated", "at", "au", "auth", "av", "available", "aw", "away", "awfully", "ax", "ay", "az", "b", "b1", "b2", "b3", "ba", "back", "bc", "bd", "be", "became", "because", "become", "becomes", "becoming", "been", "before", "beforehand", "begin", "beginning", "beginnings", "begins", "behind", "being", "believe", "below", "beside", "besides", "best", "better", "between", "beyond", "bi", "bill", "biol", "bj", "bk", "bl", "bn", "both", "bottom", "bp", "br", "brief", "briefly", "bs", "bt", "bu", "but", "bx", "by", "c", "c1", "c2", "c3", "ca", "call", "came", "can", "cannot", "cant", "can't", "cause", "causes", "cc", "cd", "ce", "certain", "certainly", "cf", "cg", "ch", "changes", "ci", "cit", "cj", "cl", "clearly", "cm", "c'mon", "cn", "co", "com", "come", "comes", "con", "concerning", "consequently", "consider", "considering", "contain", "containing", "contains", "corresponding", "could", "couldn", "couldnt", "couldn't", "course", "cp", "cq", "cr", "cry", "cs", "c's", "ct", "cu", "currently", "cv", "cx", "cy", "cz", "d", "d2", "da", "date", "dc", "dd", "de", "definitely", "describe", "described", "despite", "detail", "df", "di", "did", "didn", "didn't", "different", "dj", "dk", "dl", "do", "does", "doesn", "doesn't", "doing", "don", "done", "don't", "down", "downwards", "dp", "dr", "ds", "dt", "du", "due", "during", "dx", "dy", "e", "e2", "e3", "ea", "each", "ec", "ed", "edu", "ee", "ef", "effect", "eg", "ei", "eight", "eighty", "either", "ej", "el", "eleven", "else", "elsewhere", "em", "empty", "en", "end", "ending", "enough", "entirely", "eo", "ep", "eq", "er", "es", "especially", "est", "et", "et-al", "etc", "eu", "ev", "even", "ever", "every", "everybody", "everyone", "everything", "everywhere", "ex", "exactly", "example", "except", "ey", "f", "f2", "fa", "far", "fc", "few", "ff", "fi", "fifteen", "fifth", "fify", "fill", "find", "fire", "first", "five", "fix", "fj", "fl", "fn", "fo", "followed", "following", "follows", "for", "former", "formerly", "forth", "forty", "found", "four", "fr", "from", "front", "fs", "ft", "fu", "full", "further", "furthermore", "fy", "g", "ga", "gave", "ge", "get", "gets", "getting", "gi", "give", "given", "gives", "giving", "
s", "xt", "xv", "xx", "y", "y2", "yes", "yet", "yj", "yl", "you", "youd", "you'd", "you'll", "your", "youre", "you're", "yours", "yourself", "yourselves", "you've", "yr", "ys", "yt", "z", "zero", "zi", "zz",'a','able','about','across','after','all','almost','also','am','among','an','and','any','are','as','at','be','because','been','but','by','can','cannot','could','dear','did','do','does','either','else','ever','every','for','from','get','got','had','has','have','he','her','hers','him','his','how','however','i','if','in','into','is','it','its','just','least','let','like','likely','may','me','might','most','must','my','neither','no','nor','not','of','off','often','on','only','or','other','our','own','rather','said','say','says','she','should','since','so','some','than','that','the','their','them','then','there','these','they','this','tis','to','too','twas','us','wants','was','we','were','what','when','where','which','while','who','whom','why','will','with','would','yet','you','your', '&amp;']

for word in word_list:
    if word not in stops:
        stops.add(word)

print(sorted(stops))
# Out:
# ['&amp;', '0o', '0s', '3a', '3b', '3d', '6b', '6o', 'a', "a's", 'a1', 'a2', 'a3', 'a4', 'ab', 'able', 'about', 'above', 'abst', 'ac', 'accordance', 'according', 'accordingly', 'across', 'act', 'actually', 'ad', 'added', 'adj', 'ae', 'af', 'affected', 'affecting', 'affects', 'after', 'afterwards', 'ag', 'again', 'against', 'ah', 'ain', "ain't", 'aj', 'al', 'all', 'allow', 'allows', 'almost', 'alone', 'along', 'already', 'also', 'although', 'always', 'am', 'among', 'amongst', 'amoungst', 'amount', 'amp', 'an', 'and', 'announce', 'another', 'any', 'anybody', 'anyhow', 'anymore', 'anyone', 'anything', 'anyway', 'anyways', 'anywhere', 'ao', 'ap', 'apart', 'apparently', 'appear', 'appreciate', 'appropriate', 'approximately', 'ar', 'are', 'aren', "aren't", 'arent', 'arise', 'around', 'as', 'aside', 'ask', 'asking', 'associated', 'at', 'au', 'auth', 'av', 'available', 'aw', 'away', 'awfully', 'ax', 'ay', 'az', 'b', 'b1', 'b2', 'b3', 'ba', 'back', 'bc', 'bd', 'be', 'became', 'because', 'becom
# ...

# %%
# Define a function to remove stopwords from a text string
def remove_stopwords(text):
    if isinstance(text, str):
        words = text.split()
        filtered_words = [word for word in words if word.lower() not in stops]
        return ' '.join(filtered_words)
    else:
        return text

# %%
# Apply the remove_stopwords function to the Translated Cleaned Text column
df_all_2['translated cleaned'] = df_all_2['translated cleaned'].apply(remove_stopwords)

# %%
for text in df_all_2['translated cleaned']:
    if isinstance(text, str) and "amp" in text:
        print(text)
# Out:
# nice eat hot nasi lemak fried kampung chicken iced tea weekend morning nasi lemak tree vansa maju god
# misses traveling driving country depart early morning dawn highway petrol station long chat car eat snack car meal rampr change drivers trip fun
# jampt brothers pick sambal nyet parcel day lorry times day chili bought day ship
# rampr stopover moving heart
# younger brothers sisters campus things focused friends betraying friends
# ramadan market allowed covidthemed menus pkp fatty rice lung mussels pedal viral john bread cornrona water pandemilk tea murtavacc northern soup vermicelli lamp mask
# dont personally pick phone ampdiscuss public statement natural provide public counter argument aim provide clear message public infallible public figures
# dont personally pick phone ampdiscuss public statement natural provide public counter argument aim provide clear message public infallible public figures
# ...

# %%
df_all_2.to_csv("1.1 Cleaning Output.csv")
